# %% [markdown]
# #   3주차

# %% [markdown]
# 파이썬 로그 출력하기

# %%
print("안녕하세요.")
# Out:
# 안녕하세요.

# %%
1 + 9
# Out:
# 10

# %% [markdown]
# 셀 순서 중요도

# %%
x = 10
print(x)
# Out:
# 10

# %%
print(x + 90)
# Out:
# 100

# %% [markdown]
# #   변수

# %%
age = 20
score = 80

print(age)
print(score)
print(age + score)
# Out:
# 20
# 80
# 100

# %% [markdown]
# 숫자와 문자열

# %%
name = "park"
year = 2026

print(name)
print(year)
print(type(name))
print(type(year))
# Out:
# park
# 2026
# <class 'str'>
# <class 'int'>

# %% [markdown]
# 문자열 예시

# %%
first = "machine"
second = "learning"

print(first + second)
print(first + " " + second)
# Out:
# machinelearning
# machine learning

# %%
major = "AI응용프로그래밍"

print(major)
print("수업명: "+ major)
print("수업명: ", major)
# Out:
# AI응용프로그래밍
# 수업명: AI응용프로그래밍
# 수업명:  AI응용프로그래밍

# %% [markdown]
# 리스트

# %%
scores = [10, 20 ,30, 40 ,50]

print(scores)
print(scores[1])
print(len(scores))

scores.append(60)
print(scores)
print(len(scores))
# Out:
# [10, 20, 30, 40, 50]
# 20
# 5
# [10, 20, 30, 40, 50, 60]
# 6

# %%
scores[5]=100
print(scores)
# Out:
# [10, 20, 30, 40, 50, 100]

# %%
scores= [ 60,70,80,90,100]
print(scores)
# Out:
# [60, 70, 80, 90, 100]

# %% [markdown]
# 반복문

# %%
for score in scores:
    print("점수: ",score)
# Out:
# 점수:  60
# 점수:  70
# 점수:  80
# 점수:  90
# 점수:  100

# %% [markdown]
# 조건문

# %%
temp =8

if temp>=20:
    print("덥다")
elif temp >=10:
    print("따듯함")
elif temp >=0:
    print("춥다")
else:
    print("매우 춥다")
# Out:
# 춥다

# %%
number = 7

if number % 2 == 0:
    print("짝수")
else:
    print("홀수")
# Out:
# 홀수

# %% [markdown]
# 반복문과 조건문

# %%
scores = [42 , 60 , 77 , 89 , 20]
for score in scores:
    if score>=60:
        print(f'{score}점은 합격입니다')
    else:
        print(f'{score}점은 불합격입니다')
# Out:
# 42점은 불합격입니다
# 60점은 합격입니다
# 77점은 합격입니다
# 89점은 합격입니다
# 20점은 불합격입니다

# %% [markdown]
# 함수

# %%
def greet(name):
    print(f'{name}님, 안녕하세요')
greet("대림대")
# Out:
# 대림대님, 안녕하세요

# %%
def add_number(a,b):
    return (a+b)

print(add_number(1,2))
# Out:
# 3

# %%
numbers = [1,2,3,4,5]

total = 0
for i in numbers:
    total+=i

print("합계:" ,total)
# Out:
# 합계: 15

# %%
scores = [65,82,91,100,58,77]

total=0
for score in scores:
    if score>=70:
        total+=1
print(f'합격자는 {total}명 입니다')
# Out:
# 합격자는 4명 입니다

# %% [markdown]
# # 머신러닝

# %% [markdown]
# 라이브러리 불러오기

# %%
# %pip install pandas scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\junha\documents\python\daelim-2-3-ai-programming\venv\lib\site-packages (3.0.2)
# Requirement already satisfied: scikit-learn in c:\users\junha\documents\python\daelim-2-3-ai-programming\venv\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\junha\documents\python\daelim-2-3-ai-programming\venv\lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\junha\documents\python\daelim-2-3-ai-programming\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\junha\documents\python\daelim-2-3-ai-programming\venv\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\junha\documents\python\daelim-2-3-ai-programming\venv\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\junha\documents\python\daelim-2-3-ai-programming\venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\junha\documents\python\daelim-2-3-ai-programming\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\junha\documents\python\daelim-2-3-ai-programming\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
