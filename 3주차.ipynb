# %% [markdown]
# #   3주차

# %% [markdown]
# 파이썬 로그 출력하기

# %%
print("안녕하세요.")

# %%
1 + 9

# %% [markdown]
# 셀 순서 중요도

# %%
x = 10
print(x)

# %%
print(x + 90)

# %% [markdown]
# #   변수

# %%
age = 20
score = 80

print(age)
print(score)
print(age + score)

# %% [markdown]
# 숫자와 문자열

# %%
name = "park"
year = 2026

print(name)
print(year)
print(type(name))
print(type(year))

# %% [markdown]
# 문자열 예시

# %%
first = "machine"
second = "learning"

print(first + second)
print(first + " " + second)

# %%
major = "AI응용프로그래밍"

print(major)
print("수업명: "+ major)
print("수업명: ", major)

# %% [markdown]
# 리스트

# %%
scores = [10, 20 ,30, 40 ,50]

print(scores)
print(scores[1])
print(len(scores))

scores.append(60)
print(scores)
print(len(scores))

# %%
scores[5]=100
print(scores)

# %%
scores= [ 60,70,80,90,100]
print(scores)

# %% [markdown]
# 반복문

# %%
for score in scores:
    print("점수: ",score)

# %% [markdown]
# 조건문

# %%
temp =8

if temp>=20:
    print("덥다")
elif temp >=10:
    print("따듯함")
elif temp >=0:
    print("춥다")
else:
    print("매우 춥다")

# %%
number = 7

if number % 2 == 0:
    print("짝수")
else:
    print("홀수")

# %% [markdown]
# 반복문과 조건문

# %%
scores = [42 , 60 , 77 , 89 , 20]
for score in scores:
    if score>=60:
        print(f'{score}점은 합격입니다')
    else:
        print(f'{score}점은 불합격입니다')

# %% [markdown]
# 함수

# %%
def greet(name):
    print(f'{name}님, 안녕하세요')
greet("대림대")

# %%
def add_number(a,b):
    return (a+b)

print(add_number(1,2))

# %%
numbers = [1,2,3,4,5]

total = 0
for i in numbers:
    total+=i

print("합계:" ,total)

# %%
scores = [65,82,91,100,58,77]

total=0
for score in scores:
    if score>=70:
        total+=1
print(f'합격자는 {total}명 입니다')

# %% [markdown]
# # 머신러닝

# %% [markdown]
# 라이브러리 불러오기

# %%
# %pip install pandas scikit-learn
# Out:
# Collecting pandas
#   Using cached pandas-3.0.2-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\junha\documents\python\.venv\lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\junha\documents\python\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\junha\documents\python\.venv\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\junha\documents\python\.venv\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\junha\documents\python\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\junha\documents\python\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\junha\documents\python\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-3.0.2-cp314-cp314-win_amd64.whl (9.9 MB)
# Using cached scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
# Installing collected packages: scikit-learn, pandas
#
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    ---------------------------------------- 2/2 [pandas]
#
# Successfully installed pandas-3.0.2 scikit-learn-1.8.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
